# %%
import pandas as pd

df_강의실_월 = pd.read_excel('2024-2학기 경영대학관 강의실(2024.11.04~2024.11.10).xlsx', sheet_name = '11월04일(월)')
df_강의실_화 = pd.read_excel('2024-2학기 경영대학관 강의실(2024.11.04~2024.11.10).xlsx', sheet_name = '11월05일(화)')
df_강의실_수 = pd.read_excel('2024-2학기 경영대학관 강의실(2024.11.04~2024.11.10).xlsx', sheet_name = '11월06일(수)')
df_강의실_목 = pd.read_excel('2024-2학기 경영대학관 강의실(2024.11.04~2024.11.10).xlsx', sheet_name = '11월07일(목)')
df_강의실_금 = pd.read_excel('2024-2학기 경영대학관 강의실(2024.11.04~2024.11.10).xlsx', sheet_name = '11월08일(금)')
df_강의실_토 = pd.read_excel('2024-2학기 경영대학관 강의실(2024.11.04~2024.11.10).xlsx', sheet_name = '11월09일(토)')
df_강의실_일 = pd.read_excel('2024-2학기 경영대학관 강의실(2024.11.04~2024.11.10).xlsx', sheet_name = '11월10일(일)')

# %%
df_강의실_월
# Out:
#                 월요일 Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0            구    분        6시~       09:00:00   09:30:00   10:00:00
# 1          B113(41)        NaN            NaN        NaN        NaN
# 2          전103(90)        NaN            NaN        NaN        NaN
# 3        강111 (210)        NaN            NaN        NaN        NaN
# 4      151호\n(대연회장)        입학처            NaN        NaN        NaN
# 5           153(56)        NaN            NaN        NaN        NaN
# 6           154(56)        NaN            NaN        NaN        NaN
# 7    251(40)\n촬영강의실   23시까지 개방            NaN        NaN        NaN
# 8     252(30)\n(임시)        NaN            NaN        NaN        NaN
# 9    253(60)\n촬영강의실        NaN            NaN        NaN        NaN
# 10          254(25)        NaN  빅데이터기반경영전략(X)        NaN        NaN
# 11          255(20)        NaN            NaN        NaN        NaN
# 12          256(15)        NaN            NaN        NaN        NaN
# ...
